# %%
import pandas as pd

# %%
df = pd.read_csv('jarndyce_report.csv')

# %%
df
# Out:
#             Druid                                   Purl  \
# 0     bb018zb8894  https://purl.stanford.edu/bb018zb8894
# 1     bb122wh8873  https://purl.stanford.edu/bb122wh8873
# 2     bb403jp9042  https://purl.stanford.edu/bb403jp9042
# 3     bb456zt5479  https://purl.stanford.edu/bb456zt5479
# 4     bb705cc9370  https://purl.stanford.edu/bb705cc9370
# 5     bb737zp0787  https://purl.stanford.edu/bb737zp0787
# 6     bb846gv7194  https://purl.stanford.edu/bb846gv7194
# 7     bb851sg5107  https://purl.stanford.edu/bb851sg5107
# 8     bc067cr7596  https://purl.stanford.edu/bc067cr7596
# 9     bc647th4106  https://purl.stanford.edu/bc647th4106
# 10    bd142cw6685  https://purl.stanford.edu/bd142cw6685
# 11    bd431pt2666  https://purl.stanford.edu/bd431pt2666
# 12    bd537jh1546  https://purl.stanford.edu/bd537jh1546
# 13    bd949rr1856  https://purl.stanford.edu/bd949rr1856
# 14    bf220qb2659  https://purl.stanford.edu/bf220qb2659
# ...

# %%
source_ids = df["Source Id"]

# %%
df["source_id"] = pd.Series([source.replace("sul:", "") for source in source_ids])

# %%
df
# Out:
#             Druid                                   Purl  \
# 0     bb018zb8894  https://purl.stanford.edu/bb018zb8894
# 1     bb122wh8873  https://purl.stanford.edu/bb122wh8873
# 2     bb403jp9042  https://purl.stanford.edu/bb403jp9042
# 3     bb456zt5479  https://purl.stanford.edu/bb456zt5479
# 4     bb705cc9370  https://purl.stanford.edu/bb705cc9370
# 5     bb737zp0787  https://purl.stanford.edu/bb737zp0787
# 6     bb846gv7194  https://purl.stanford.edu/bb846gv7194
# 7     bb851sg5107  https://purl.stanford.edu/bb851sg5107
# 8     bc067cr7596  https://purl.stanford.edu/bc067cr7596
# 9     bc647th4106  https://purl.stanford.edu/bc647th4106
# 10    bd142cw6685  https://purl.stanford.edu/bd142cw6685
# 11    bd431pt2666  https://purl.stanford.edu/bd431pt2666
# 12    bd537jh1546  https://purl.stanford.edu/bd537jh1546
# 13    bd949rr1856  https://purl.stanford.edu/bd949rr1856
# 14    bf220qb2659  https://purl.stanford.edu/bf220qb2659
# ...

# %%
df.to_csv("jarndyce_ids.csv")
